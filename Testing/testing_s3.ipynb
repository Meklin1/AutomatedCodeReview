# %% [markdown]
# # Testing comments generated by S3 method (Qwen-2.5-Coder-Instruct with CoT and USC)

# %%
# %%capture
# !pip install pip3-autoremove
# !pip-autoremove torch torchvision torchaudio -y
# !pip install torch torchvision torchaudio xformers --index-url https://download.pytorch.org/whl/cu121
# !pip install unsloth

# %%
import torch
import os
from unsloth import FastLanguageModel
from unsloth.chat_templates import get_chat_template
from google.colab import drive
import json
import time
import os
from typing import List, Dict, Any, Optional
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DRIVE_ROOT   = "/content/drive/MyDrive"
INPUT_FILE   = "test_final.jsonl"
PROJECT_PATH  = os.path.join(DRIVE_ROOT, "CodeReview")
OUTPUT_FILE  = os.path.join(PROJECT_PATH, "test_s3.jsonl")
MODEL_NAME   = "unsloth/Qwen2.5-Coder-7B-Instruct"

MAX_SEQ_LENGTH  = 10000
MAX_NEW_TOKENS  = 512
K_CANDIDATES    = 3
TEMP            = 0.6
CACHE_PATHS     = False

# %%
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name      = MODEL_NAME,
    max_seq_length  = MAX_SEQ_LENGTH,
    dtype           = None,          # autodetect fp16/bf16
    load_in_4bit    = True,          # 4-bit quant for memory savings
)

FastLanguageModel.for_inference(model)                # enable 2× fast path

tokenizer = get_chat_template(
    tokenizer, chat_template="qwen-2.5",
    mapping={"role":"role","content":"content",
             "user":"user","assistant":"assistant"},
)
tokenizer.pad_token = tokenizer.eos_token
_ = model.generate(**tokenizer("warm-up", return_tensors="pt").to(model.device),
                   max_new_tokens=1)

# %% [markdown]
# Prompts used in testing

# %%
# System prompt with reasoning
system_prompt_content ="""You are an expert in finding Java code issues.

GOAL:
Review Java diffs for "evident defects" in *changed lines only*.
* "Evident defect": Violates best practices, bug (logic, runtime, security), impairs performance or hurts readability/maintainability.
* Output polite, concise and actionable feedback on defects, or `NoComment`.

WORKFLOW (internal):
1.  Input: Parse <DIFF>, <CODE>. Focus on <DIFF> hunks; use <CODE> for context.
2.  Analysis (changed lines per hunk):
    a.   Find evident defects (logic, security, performance, style, best practices, error handling, concurrency).
3.  Output:
    a.  `<REASONING>`: Explain analysis of changed lines & why issues are/aren't evident defects. Use Markdown lists if needed.
    b.  Final Review: If defects, list as `* Concise problem & fix if not complex.`, else `NoComment`.

OUTPUT RULES:
1.  Structure: `<REASONING>...</REASONING>` block first, then Final Review on a new line.
2.  Final Review Format:
    * Defects: Markdown bullets (`* Problem. Fix.`), ≤2 sentences/bullet. No extra headings.
    * No defects: **Exactly** `NoComment`.
3.  Content Constraints:
    * Feedback on changed lines only.
"""

FEW_SHOT_EXAMPLES: List[Dict[str, str]] = [
    # Scenario 1: No issues found
    dict(
        patch = """@@ -101,5 +101,5 @@ public class Example {
                -       for (int i = 0; i < items.size(); i++) {
                +       for (int index = 0; index < items.size(); index++) {
                        String item = items.get(index);
                        process(item);
                    }""",
        code = """101|   public void processList(List<String> items) {
                  102|     for (int index = 0; index < items.size(); index++) {
                  103|       String item = items.get(index);
                  104|       process(item);
                  105|   }}""",
        review = """<REASONING>
                    * Diff: Loop variable 'i' renamed to 'index'.
                    * Analysis: Change is purely stylistic, improving readability. No logic change, no new defect introduced in changed lines.
                    * Conclusion: No evident defects.
                    </REASONING>
                    NoComment"""),

    # Scenario 2: Blank line in imports (style defect)
    dict(
        patch = """@@ -14,7 +14,7 @@ import org.slf4j.Logger;
                  import org.slf4j.LoggerFactory;

                  import java.io.File;
                  import java.net.URI;
                  -import java.util.concurrent.Semaphore;""",
        code = """14| import org.slf4j.LoggerFactory;
                  15|
                  16| import java.io.File;
                  17| import java.net.URI;
                  18|
                  19|
                  20| public class GitRepository implements Repository {
                  21|   private final static Logger LOGGER = LoggerFactory.getLogger(GitRepository.class);""",
        review = """<REASONING>
                  * Diff: Import removed. Changed lines include the new blank line at line 15.
                  * Analysis: The new blank line at line 15 and line 18 (a changed line) violates common Java import style (readability concern).
                  * Conclusion: Minor style defect.
                  </REASONING>
                  * Line 15 and 18: Imports should not include empty lines as breaks, except between imports and static imports."""),

    # Scenario 3: Wrapper vs. primitive type (best practice/performance)
    dict(
        patch = """@@ -159,6 +159,20 @@ public final class Require {
                        return number;
                      }

                  +   public static double positive(String argName, Double number, String message) {
                  +     if (number == null) {
                  +       throw new IllegalArgumentException(String.format(ARG_MUST_BE_SET, argName));
                  +     }
                  +     if (number <= 0) {
                  +       if (message == null) {
                  +         throw new IllegalArgumentException(argName + " must be greater than 0");
                  +       } else {
                  +         throw new IllegalArgumentException(message);
                  +       }
                  +     }
                  +     return number;
                  +   }
                  +
                      public static int positive(String argName, Integer number) {
                        return positive(argName, number, null);
                      }""",
        code = """172|   public static double positive(String argName, Double number, String message) {
                  173|     if (number == null) {
                  174|       throw new IllegalArgumentException(String.format(ARG_MUST_BE_SET, argName));
                  175|     }
                  176|     if (number <= 0) {
                  177|       if (message == null) {
                  178|         throw new IllegalArgumentException(argName + " must be greater than 0");
                  179|       } else {
                  180|         throw new IllegalArgumentException(message);
                  181|       }
                  182|     }
                  183|     return number; // Unnecessary unboxing
                  184|   }
                  185|
                  186|   public static int positive(String argName, Integer number) {""",
        review = """<REASONING>
                    * Diff: New method `positive(String, Double, String)` added (lines 172-184 are changed).
                    * Analysis:
                        * Parameter `number` (line 172) is `Double`, method returns `double`.
                        * This requires a null check (lines 173-175) and causes unboxing at return (line 183).
                        * Using primitive `double` for parameter `number` avoids null checks and unboxing. This is a best practice violation.
                    * Conclusion: Evident defect (best practice, performance).
                    </REASONING>
                    * Line 172: For parameter `number` consider using primitive type `double`. This avoids unnecessary unboxing at line 183 and makes the null-check redundant.""",
    ),


    # Scenario 4: No relevant warning, LLM finds defect independently (resource leak)
    dict(
        patch = """@@ -20,3 +20,5 @@ import java.io.IOException;
                    public class FileReaderUtil {
                  -     public String readFile(String filePath) throws IOException {
                  -         BufferedReader reader = new BufferedReader(new FileReader(filePath));
                  -         return reader.readLine();
                  +     public String readFile(String filePath) throws IOException {
                  +         BufferedReader reader = new BufferedReader(new FileReader(filePath)); // Resource opened (changed line)
                  +         String line = reader.readLine(); // Changed line
                  +         // Reader not closed
                  +         return line; // Changed line
                  """,
        code = """
         18| import java.io.BufferedReader;
         19| import java.io.FileReader;
         20| import java.io.IOException;
         21|
         22| public class FileReaderUtil {
         23|   public String readFile(String filePath) throws IOException {
         24|     BufferedReader reader = new BufferedReader(new FileReader(filePath));
         25|     String line = reader.readLine();
         26|     return line;
         27|   }
         28| }
        """,
        review = """<REASONING>
* Diff: Method `readFile` modified. Lines 24-26 are new/changed.
* Analysis: `BufferedReader` created at changed line 24 is not closed before method returns (changed line 26). This is a resource leak (best practice violation).
* Conclusion: Evident defect.
</REASONING>
* Line 24: The `BufferedReader` (and underlying `FileReader`) is not closed. Consider using a try-with-resources statement or ensure `close()` is called in a `finally` block to prevent resource leaks.""",
    )
]


# Message builders
USER_BLOCK_TEMPLATE = """
<DIFF>
{patch}
</DIFF>

<CODE>
{code}
</CODE>
"""

# %% [markdown]
#  Utility functions

# %%
def number_lines(code: str) -> str:
    """Add line number prefix to every line of code"""
    lines = code.splitlines()
    width = len(str(len(lines)))
    return "\n".join(f"{str(i+1).rjust(width)} | {l}" for i, l in enumerate(lines))

def build_chat_messages(sample: Dict[str, Any]) -> list[Dict[str, str]]:
    """Compose few-shot + real example into chat message list."""
    msgs = [{"role":"system", "content": system_prompt_content}]

    for ex in FEW_SHOT_EXAMPLES:
        block = USER_BLOCK_TEMPLATE.format(
            patch    = ex["patch"],
            code     = number_lines(ex["code"]),
        )
        msgs += [
            {"role":"user",      "content": block},
            {"role":"assistant", "content": ex['review']},
        ]

    real_block = USER_BLOCK_TEMPLATE.format(
        patch    = sample["patch"],
        code     = number_lines(sample["code"]),
    )
    msgs.append({"role":"user", "content": real_block})
    return msgs


def parse_reasoning_and_review(full_llm_output: str) -> tuple[str, str]:
    reasoning_content = ""
    review_content = full_llm_output.strip()
    match = re.search(r"<REASONING>(.*?)</REASONING>", full_llm_output, re.DOTALL)
    if match:
        reasoning_content = match.group(1).strip()
        review_content = full_llm_output[match.end(0):].strip()
    return reasoning_content, review_content

# %% [markdown]
# Universal self consistency helpers

# %%
import re

def sample_candidate(chat_msgs, i=0) -> str:
    #  build prompt text
    prompt = tokenizer.apply_chat_template(
        chat_msgs, tokenize=False, add_generation_prompt=True
    )
    # tokenize to mapping
    enc = tokenizer(prompt, return_tensors="pt", padding=True).to(model.device)

    out_ids = model.generate(
        **enc,
        max_new_tokens = MAX_NEW_TOKENS,
        temperature    = TEMP,
        top_p          = 0.95,
        use_cache      = True,
    )
    full = tokenizer.decode(out_ids[0, enc["input_ids"].shape[1]:],
                            skip_special_tokens=True)

    reasoning, review  = parse_reasoning_and_review(full)

    print(f"\n--- Candidate {i} ---")
    print(f"Full LLM Output:\n{full}")
    print(f"Parsed Reasoning:\n{reasoning}")
    print(f"Parsed Review:\n{review}")
    print("--------------------")
    return review




def pick_with_usc(candidates: List[str]) -> str:
    bulleted = "\n\n".join(f"[{i+1}]\n{c}" for i, c in enumerate(candidates))
    selector_msgs = [
        {"role":"system",
         "content":"You are an expert reviewer. Choose the most semantically consistent variant below, "
                   "if it is poorly formated or not clear choose next most consistent variant "
                   "and reply ONLY with its number."},
        {"role":"user", "content": bulleted},
    ]

    prompt = tokenizer.apply_chat_template(
        selector_msgs, tokenize=False, add_generation_prompt=True
    )

    enc = tokenizer(prompt, return_tensors="pt", padding=True).to(model.device)
    sel_ids = model.generate(**enc, max_new_tokens=5)
    choice  = tokenizer.decode(
        sel_ids[0, enc["input_ids"].shape[1]:], skip_special_tokens=True
    ).strip()
    try:
        return candidates[int(choice) - 1]
    except (ValueError, IndexError):
        # fallback: majority vote
        return max(set(candidates), key=candidates.count)

# %% [markdown]
#  Testing pipeline

# %%
# Build a list from not already tested entries
processed: set[str] = set()
if os.path.exists(OUTPUT_FILE):
    with open(OUTPUT_FILE, encoding="utf-8") as fh:
        for line in fh:
            if not line.strip(): continue
            obj = json.loads(line)
            if "aiReviewS2" in obj:
                processed.add(obj["id"])
print(f"Already processed: {len(processed)}")

with open(INPUT_FILE, encoding="utf-8") as fh:
    dataset = [json.loads(l) for l in fh if l.strip()]

todo = [s for s in dataset if s["id"] not in processed]
print(f"Remaining: {len(todo)} / {len(dataset)}\n")




saved = 0
tic   = time.time()

if PROJECT_PATH and not os.path.exists(PROJECT_PATH):
    os.makedirs(PROJECT_PATH)

with open(OUTPUT_FILE, "a", encoding="utf-8") as sink:
    for sample in todo:
        # build chat with exemplars
        chat = build_chat_messages(sample)

        # generate k diverse reasoning paths
        paths = [sample_candidate(chat, i) for i in range(K_CANDIDATES)]

        # USC selection
        best_review = pick_with_usc(paths)
        print(f"BEST: {best_review}")
        sample["aiReviewS2"] = best_review
        if CACHE_PATHS:
            sample["usc_candidates"] = paths

        # save every tested entry
        sink.write(json.dumps(sample, ensure_ascii=False) + "\n")
        saved += 1
        print(f"✓ {saved}/{len(todo)}  id={sample['id']}")

toc = time.time()
print(f"\n✅ Done.  Wrote {saved} samples in {toc-tic:.1f}s")
# Out:
# Already processed: 539
# Remaining: 1940 / 2708
#
#
# --- Candidate 0 ---
# Full LLM Output:
# <REASONING>
#                   * Diff: Removed unused imports for `org.joda.time.format.DateTimeFormat` and `org.joda.time.format.DateTimeFormatter`.
#                   * Analysis: The removal of these unused imports is a minor cleanup that improves the project's cleanliness without introducing any bugs or significant changes.
#                   * Conclusion: No evident defect.
#                   </REASONING>
#                   NoComment
# Parsed Reasoning:
# * Diff: Removed unused imports for `org.joda.time.format.DateTimeFormat` and `org.joda.time.format.DateTimeFormatter`.
#                   * Analysis: The removal of these unused imports is a minor cleanup that improves the project's cleanliness without introducing any bugs or significant changes.
#                   * Conclusion: No evident defect.
# Parsed Review:
# NoComment
# --------------------
#
# --- Candidate 1 ---
# Full LLM Output:
# <REASONING>
# * Diff: Removed Joda-Time related imports.
# * Analysis:
#   * Removing unused imports improves code cleanliness and reduces potential conflicts.
#   * No evidence of bugs, performance issues, or readability concerns.
# * Conclusion: No evident defects.
# </REASONING>
# NoComment
# Parsed Reasoning:
# * Diff: Removed Joda-Time related imports.
# * Analysis:
#   * Removing unused imports improves code cleanliness and reduces potential conflicts.
#   * No evidence of bugs, performance issues, or readability concerns.
# * Conclusion: No evident defects.
# Parsed Review:
# NoComment
# --------------------
#
# --- Candidate 2 ---
# Full LLM Output:
# <REASONING>
#                   * Diff: Removed import statements for `org.joda.time.format.DateTimeFormat` and `org.joda.time.format.DateTimeFormatter`.
#                   * Analysis:
#                         * These imports were likely unused after removal. However, without knowing the full context, it's possible they were still used elsewhere in the project.
#                         * If these classes were indeed used elsewhere, their removal could cause compilation errors. If they were not used, removing them improves cleanliness.
#                   * Conclusion: Potentially minor stylistic improvement, but could introduce bugs if previously used elsewhere.
#                   </REASONING>
#                   NoComment
# Parsed Reasoning:
# * Diff: Removed import statements for `org.joda.time.format.DateTimeFormat` and `org.joda.time.format.DateTimeFormatter`.
#                   * Analysis:
#                         * These imports were likely unused after removal. However, without knowing the full context, it's possible they were still used elsewhere in the project.
#                         * If these classes were indeed used elsewhere, their removal could cause compilation errors. If they were not used, removing them improves cleanliness.
#                   * Conclusion: Potentially minor stylistic improvement, but could introduce bugs if previously used elsewhere.
# Parsed Review:
# NoComment
# --------------------
# BEST: NoComment
# ✓ 1/1940  id=27467
#
# --- Candidate 0 ---
# Full LLM Output:
# <REASONING>
#                     * Diff: Import `azkaban.event.Event.Type` added.
#                     * Analysis: Adding an unused import (line 77) can lead to confusion and potential future issues when the import is actually needed without causing any immediate defect.
#                     * Conclusion: Minor style defect.
#                     </REASONING>
#                     * Line 77: Remove unused import `azkaban.event.Event.Type`.
# Parsed Reasoning:
# * Diff: Import `azkaban.event.Event.Type` added.
#                     * Analysis: Adding an unused import (line 77) can lead to confusion and potential future issues when the import is actually needed without causing any immediate defect.
#                     * Conclusion: Minor style defect.
# Parsed Review:
# * Line 77: Remove unused import `azkaban.event.Event.Type`.
# --------------------
#
# --- Candidate 1 ---
# Full LLM Output:
# <REASONING>
#                     * Diff: Import `azkaban.event.Event.Type` added (line 5).
#                     * Analysis: Adding a specific import for `Event.Type` does not introduce any bugs, performance issues, or readability concerns. It is a minor addition that adheres to best practices.
#                     * Conclusion: No evident defect.
#                     </REASONING>
#                     NoComment
# Parsed Reasoning:
# * Diff: Import `azkaban.event.Event.Type` added (line 5).
#                     * Analysis: Adding a specific import for `Event.Type` does not introduce any bugs, performance issues, or readability concerns. It is a minor addition that adheres to best practices.
#                     * Conclusion: No evident defect.
# Parsed Review:
# NoComment
# --------------------
#
# --- Candidate 2 ---
# Full LLM Output:
# <REASONING>
#                     * Diff: Import `azkaban.event.Event.Type` added.
#                     * Analysis: The addition of `Type` from `azkaban.event.Event` seems unrelated to the original diff. However, it could imply a larger refactoring that might have been missed in the provided context.
#                     * Conclusion: No evident defects.
#                     </REASONING>
#                     NoComment
# Parsed Reasoning:
# * Diff: Import `azkaban.event.Event.Type` added.
#                     * Analysis: The addition of `Type` from `azkaban.event.Event` seems unrelated to the original diff. However, it could imply a larger refactoring that might have been missed in the provided context.
#                     * Conclusion: No evident defects.
# Parsed Review:
# NoComment
# --------------------
# BEST: NoComment
# ✓ 2/1940  id=13508
#
# --- Candidate 0 ---
# Full LLM Output:
# <REASONING>
#                   * Diff: Class name changed from `SynchronizedReportListener` to `ThreadSafeReportListener`.
#                   * Analysis: This change is purely renaming the class, which does not affect the functionality or correctness of the code. There are no evident defects related to logic, security, performance, or readability/maintainability.
#                   * Conclusion: No evident defect.
#                   </REASONING>
#                   NoComment
# Parsed Reasoning:
# * Diff: Class name changed from `SynchronizedReportListener` to `ThreadSafeReportListener`.
#                   * Analysis: This change is purely renaming the class, which does not affect the functionality or correctness of the code. There are no evident defects related to logic, security, performance, or readability/maintainability.
#                   * Conclusion: No evident defect.
# Parsed Review:
# NoComment
# --------------------
#
# --- Candidate 1 ---
# Full LLM Output:
# <REASONING>
#                     * Diff: Class name changed from `SynchronizedReportListener` to `ThreadSafeReportListener`.
#                     * Analysis: Renaming a class does not introduce bugs, performance issues, or readability problems unless there are external dependencies that need updating.
#                     * Conclusion: No evident defect.
#                     </REASONING>
#                     NoComment
# Parsed Reasoning:
# * Diff: Class name changed from `SynchronizedReportListener` to `ThreadSafeReportListener`.
#                     * Analysis: Renaming a class does not introduce bugs, performance issues, or readability problems unless there are external dependencies that need updating.
#                     * Conclusion: No evident defect.
# Parsed Review:
# NoComment
# --------------------
#
# --- Candidate 2 ---
# Full LLM Output:
# <REASONING>
#                     * Diff: Class name changed from `SynchronizedReportListener` to `ThreadSafeReportListener`.
#                     * Analysis: Renaming the class does not change its functionality. However, renaming classes can sometimes make them harder to understand or track. In this case, adding `ThreadSafe` to the name might imply that the class ensures thread safety, which isn't explicitly clear from the implementation.
#                     * Conclusion: Minor readability concern.
#                     </REASONING>
#                     * Class name: Consider whether renaming `ThreadSafeReportListener` to something more descriptive or removing the prefix would improve clarity.
# Parsed Reasoning:
# * Diff: Class name changed from `SynchronizedReportListener` to `ThreadSafeReportListener`.
#                     * Analysis: Renaming the class does not change its functionality. However, renaming classes can sometimes make them harder to understand or track. In this case, adding `ThreadSafe` to the name might imply that the class ensures thread safety, which isn't explicitly clear from the implementation.
#                     * Conclusion: Minor readability concern.
# Parsed Review:
# * Class name: Consider whether renaming `ThreadSafeReportListener` to something more descriptive or removing the prefix would improve clarity.
# --------------------
# BEST: NoComment
# ✓ 3/1940  id=11869
#
# --- Candidate 0 ---
# Full LLM Output:
# <REASONING>
#                   * Diff: Large number of imports added (line 20-41).
#                   * Analysis:
#                       * Adding numerous imports does not introduce bugs, errors, or significant performance issues.
#                       * It slightly reduces readability but does not impair maintainability unless these imports are unused.
#                   * Conclusion: Minor readability concern.
#                   </REASONING>
#                   NoComment
# Parsed Reasoning:
# * Diff: Large number of imports added (line 20-41).
#                   * Analysis:
#                       * Adding numerous imports does not introduce bugs, errors, or significant performance issues.
#                       * It slightly reduces readability but does not impair maintainability unless these imports are unused.
#                   * Conclusion: Minor readability concern.
# Parsed Review:
# NoComment
# --------------------
#
# --- Candidate 1 ---
# Full LLM Output:
# <REASONING>
#                     * Diff: Class `OrcMetrics` modified. Lines 20-78 are new/added.
#                     * Analysis:
#                         * Large amount of imports added, but no new functionality or changes to existing methods.
#                         * Existing methods (fromInputFile and fromWriter) are placeholders with incomplete implementations and commented-out TODOs.
#                         * No evident defects identified in the changed lines.
#                     * Conclusion: No evident defect.
#                     </REASONING>
#                     NoComment
# Parsed Reasoning:
# * Diff: Class `OrcMetrics` modified. Lines 20-78 are new/added.
#                     * Analysis:
#                         * Large amount of imports added, but no new functionality or changes to existing methods.
#                         * Existing methods (fromInputFile and fromWriter) are placeholders with incomplete implementations and commented-out TODOs.
#                         * No evident defects identified in the changed lines.
#                     * Conclusion: No evident defect.
# Parsed Review:
# NoComment
# --------------------
#
# --- Candidate 2 ---
# Full LLM Output:
# <REASONING>
#                     * Diff: Imports and class content updated (many lines changed).
#                     * Analysis:
#                         * The addition of numerous imports (lines 21-60) suggests the class has become more complex.
#                         * There are no evident defects in terms of bugs, performance, or readability issues in the changed lines.
#                     * Conclusion: No evident defect.
#                     </REASONING>
#                     NoComment
# Parsed Reasoning:
# * Diff: Imports and class content updated (many lines changed).
#                     * Analysis:
#                         * The addition of numerous imports (lines 21-60) suggests the class has become more complex.
#                         * There are no evident defects in terms of bugs, performance, or readability issues in the changed lines.
#                     * Conclusion: No evident defect.
# Parsed Review:
# NoComment
# --------------------
# BEST: NoComment
# ✓ 4/1940  id=13608
#
# --- Candidate 0 ---
# Full LLM Output:
# <REASONING>
#                     * Diff: Default method `encryption()` removed, interface now declares it as abstract (changed lines 66-69).
#                     * Analysis: Removing the default implementation and making the method abstract improves API design by forcing concrete implementations to provide their own encryption logic. This aligns with good design principles.
#                     * Conclusion: No evident defects.
#                     </REASONING>
#                     NoComment
# Parsed Reasoning:
# * Diff: Default method `encryption()` removed, interface now declares it as abstract (changed lines 66-69).
#                     * Analysis: Removing the default implementation and making the method abstract improves API design by forcing concrete implementations to provide their own encryption logic. This aligns with good design principles.
#                     * Conclusion: No evident defects.
# Parsed Review:
# NoComment
# --------------------
#
# --- Candidate 1 ---
# Full LLM Output:
# <REASONING>
#                   * Diff: Removed default method `encryption()` with comment indicating work in progress.
#                   * Analysis: Removing a default method that was previously implemented (now throws `UnsupportedOperationException`) introduces a logical inconsistency in the interface. This could lead to runtime errors when calling `encryption()` on implementations that expect the default behavior.
#                   * Conclusion: Evident defect (bug, logic).
#                   </REASONING>
#                   * Line 66: Removing the default implementation of `encryption()` means that implementations will now throw an `UnsupportedOperationException` when calling this method. Ensure all implementations either provide their own implementation or handle this appropriately.
# Parsed Reasoning:
# * Diff: Removed default method `encryption()` with comment indicating work in progress.
#                   * Analysis: Removing a default method that was previously implemented (now throws `UnsupportedOperationException`) introduces a logical inconsistency in the interface. This could lead to runtime errors when calling `encryption()` on implementations that expect the default behavior.
#                   * Conclusion: Evident defect (bug, logic).
# Parsed Review:
# * Line 66: Removing the default implementation of `encryption()` means that implementations will now throw an `UnsupportedOperationException` when calling this method. Ensure all implementations either provide their own implementation or handle this appropriately.
# --------------------
#
# --- Candidate 2 ---
# Full LLM Output:
# <REASONING>
#                     * Diff: Default method `encryption()` removed, replaced by non-default method.
#                     * Analysis: Removing a default method without providing a replacement can break compatibility with existing implementations that depend on it. Additionally, the comment "TODO coming soon" implies this was intended as a future enhancement, but now it's permanently gone without a clear alternative provided.
#                     * Conclusion: Evident defect (compatibility, design).
#                     </REASONING>
#                     * None of the changed lines contain bugs, improve performance, or significantly hurt readability/maintainability. However, the removal of a default method and its associated comment suggest a significant API change that could affect downstream users.
# Parsed Reasoning:
# * Diff: Default method `encryption()` removed, replaced by non-default method.
#                     * Analysis: Removing a default method without providing a replacement can break compatibility with existing implementations that depend on it. Additionally, the comment "TODO coming soon" implies this was intended as a future enhancement, but now it's permanently gone without a clear alternative provided.
#                     * Conclusion: Evident defect (compatibility, design).
# Parsed Review:
# * None of the changed lines contain bugs, improve performance, or significantly hurt readability/maintainability. However, the removal of a default method and its associated comment suggest a significant API change that could affect downstream users.
# --------------------
# BEST: * None of the changed lines contain bugs, improve performance, or significantly hurt readability/maintainability. However, the removal of a default method and its associated comment suggest a significant API change that could affect downstream users.
# ✓ 5/1940  id=12696
#
# --- Candidate 0 ---
# Full LLM Output:
# <REASONING>
#                   * Diff: Changed default storage implementation from `LOCAL` to `DATABASE`.
#                   * Analysis:
#                         * Changing the default storage implementation from `LOCAL` to `DATABASE` could affect application behavior and performance, depending on the specifics of how each storage type is implemented.
#                         * This change introduces a potential risk without immediate evidence of bugs or performance issues.
#                         * However, it's a significant structural change that might require thorough testing.
#                   * Conclusion: Potential defect (performance, behavior).
#                   </REASONING>
#                   * Default storage implementation has been changed from `LOCAL` to `DATABASE`. Ensure comprehensive testing is performed to validate the application behaves as expected with the new storage configuration.
# Parsed Reasoning:
# * Diff: Changed default storage implementation from `LOCAL` to `DATABASE`.
#                   * Analysis:
#                         * Changing the default storage implementation from `LOCAL` to `DATABASE` could affect application behavior and performance, depending on the specifics of how each storage type is implemented.
#                         * This change introduces a potential risk without immediate evidence of bugs or performance issues.
#                         * However, it's a significant structural change that might require thorough testing.
#                   * Conclusion: Potential defect (performance, behavior).
# Parsed Review:
# * Default storage implementation has been changed from `LOCAL` to `DATABASE`. Ensure comprehensive testing is performed to validate the application behaves as expected with the new storage configuration.
# --------------------
#
# --- Candidate 1 ---
# Full LLM Output:
# <REASONING>
#                   * Diff: Default value for `storageImplementation` changed from `LOCAL` to `DATABASE`.
#                   * Analysis:
#                       * This change updates the default storage type from local to database.
#                       * This could potentially impact existing configurations that rely on the previous setting.
#                       * However, it does not introduce a logic bug, performance issue, or security vulnerability.
#                   * Conclusion: No evident defect.
#                   </REASONING>
#                   NoComment
# Parsed Reasoning:
# * Diff: Default value for `storageImplementation` changed from `LOCAL` to `DATABASE`.
#                   * Analysis:
#                       * This change updates the default storage type from local to database.
#                       * This could potentially impact existing configurations that rely on the previous setting.
#                       * However, it does not introduce a logic bug, performance issue, or security vulnerability.
#                   * Conclusion: No evident defect.
# Parsed Review:
# NoComment
# --------------------
#
# --- Candidate 2 ---
# Full LLM Output:
# <REASONING>
#                     * Diff: Default value for `storageImplementation` changed from `LOCAL` to `DATABASE`.
#                     * Analysis: Changing the default storage implementation from `LOCAL` to `DATABASE` without additional configuration or checks could lead to bugs or unexpected behavior. This is a potential logic defect.
#                     * Conclusion: Evident defect.
#                     </REASONING>
#                     * The default storage implementation has been changed from `LOCAL` to `DATABASE`. Ensure that all necessary configurations and checks are in place to support the new default.
# Parsed Reasoning:
# * Diff: Default value for `storageImplementation` changed from `LOCAL` to `DATABASE`.
#                     * Analysis: Changing the default storage implementation from `LOCAL` to `DATABASE` without additional configuration or checks could lead to bugs or unexpected behavior. This is a potential logic defect.
#                     * Conclusion: Evident defect.
# Parsed Review:
# * The default storage implementation has been changed from `LOCAL` to `DATABASE`. Ensure that all necessary configurations and checks are in place to support the new default.
# --------------------
# BEST: NoComment
# ✓ 6/1940  id=12804
#
# --- Candidate 0 ---
# Full LLM Output:
# <REASONING>
#                     * Diff: `java.util.stream.Collectors` imported and unused.
#                     * Analysis: The import statement for `Collectors` is present but not used anywhere in the provided diff. This is a stylistic choice that does not affect the functionality of the code.
#                     * Conclusion: No evident defect.
#                     </REASONING>
#                     NoComment
# Parsed Reasoning:
# * Diff: `java.util.stream.Collectors` imported and unused.
#                     * Analysis: The import statement for `Collectors` is present but not used anywhere in the provided diff. This is a stylistic choice that does not affect the functionality of the code.
#                     * Conclusion: No evident defect.
# Parsed Review:
# NoComment
# --------------------
#
# --- Candidate 1 ---
# Full LLM Output:
# <REASONING>
#                     * Diff: Imports added (lines 24-25 and 27-28).
#                     * Analysis: Addition of `java.util.stream.Collectors` (lines 24-25) and `org.apache.iceberg.CatalogProperties` (lines 27-28) seems to be related to stream operations and iceberg properties. Without further context, it's difficult to determine if these additions cause any evident defects. However, adding unused imports can lead to clutter and potential confusion.
#                     * Conclusion: Potential minor style defect due to unused imports.
#                     </REASONING>
#                     * Lines 24-25 and 27-28: Consider removing unused imports to keep the code clean and reduce clutter.
# Parsed Reasoning:
# * Diff: Imports added (lines 24-25 and 27-28).
#                     * Analysis: Addition of `java.util.stream.Collectors` (lines 24-25) and `org.apache.iceberg.CatalogProperties` (lines 27-28) seems to be related to stream operations and iceberg properties. Without further context, it's difficult to determine if these additions cause any evident defects. However, adding unused imports can lead to clutter and potential confusion.
#                     * Conclusion: Potential minor style defect due to unused imports.
# Parsed Review:
# * Lines 24-25 and 27-28: Consider removing unused imports to keep the code clean and reduce clutter.
# --------------------
#
# --- Candidate 2 ---
# Full LLM Output:
# <REASONING>
#                   * Diff: Added imports for `java.util.stream.Collectors`.
#                   * Analysis: Addition of `Collectors` import does not introduce any bugs, performance issues, or readability problems. It is a standard utility class import that enhances stream operations.
#                   * Conclusion: No evident defect.
#                   </REASONING>
#                   NoComment
# Parsed Reasoning:
# * Diff: Added imports for `java.util.stream.Collectors`.
#                   * Analysis: Addition of `Collectors` import does not introduce any bugs, performance issues, or readability problems. It is a standard utility class import that enhances stream operations.
#                   * Conclusion: No evident defect.
# Parsed Review:
# NoComment
# --------------------
# BEST: NoComment
# ✓ 7/1940  id=32578
#
# --- Candidate 0 ---
# Full LLM Output:
# <REASONING>
#                     * Diff: Code in methods `createClass` and `genMultiWrapperInterface` added.
#                     * Analysis:
#                         * Code addition appears to be adding getter and setter generation logic based on `FieldConfig` objects.
#                         * However, the diff does not show how these methods (`addFieldGetter` and `addFieldSetter`) are implemented.
#                         * Without knowing the implementation details, it's hard to assess if there are any evident defects, such as bugs, security issues, or performance concerns.
#                     * Conclusion: Insufficient information to determine evident defects.
#                     </REASONING>
#                     NoComment
# Parsed Reasoning:
# * Diff: Code in methods `createClass` and `genMultiWrapperInterface` added.
#                     * Analysis:
#                         * Code addition appears to be adding getter and setter generation logic based on `FieldConfig` objects.
#                         * However, the diff does not show how these methods (`addFieldGetter` and `addFieldSetter`) are implemented.
#                         * Without knowing the implementation details, it's hard to assess if there are any evident defects, such as bugs, security issues, or performance concerns.
#                     * Conclusion: Insufficient information to determine evident defects.
# Parsed Review:
# NoComment
# --------------------
#
# --- Candidate 1 ---
# Full LLM Output:
# <REASONING>
#                     * Diff: Code snippet for generating getter and setter methods added.
#                     * Analysis: The addition of getter and setter generation logic does not introduce any bugs, performance issues, or significant readability concerns. It appears to be a straightforward enhancement.
#                     * Conclusion: No evident defects.
#                     </REASONING>
#                     NoComment
# Parsed Reasoning:
# * Diff: Code snippet for generating getter and setter methods added.
#                     * Analysis: The addition of getter and setter generation logic does not introduce any bugs, performance issues, or significant readability concerns. It appears to be a straightforward enhancement.
#                     * Conclusion: No evident defects.
# Parsed Review:
# NoComment
# --------------------
#
# --- Candidate 2 ---
# Full LLM Output:
# <REASONING>
#                     * Diff: Code snippet added to generate getter and setter methods based on `FieldConfig` settings.
#                     * Analysis: This addition adds functionality without introducing bugs, performance issues, or significant readability harm.
#                     * Conclusion: No evident defect.
#                     </REASONING>
#                     NoComment
# Parsed Reasoning:
# * Diff: Code snippet added to generate getter and setter methods based on `FieldConfig` settings.
#                     * Analysis: This addition adds functionality without introducing bugs, performance issues, or significant readability harm.
#                     * Conclusion: No evident defect.
# Parsed Review:
# NoComment
# --------------------
# BEST: NoComment
# ✓ 8/1940  id=6359
#
# --- Candidate 0 ---
# Full LLM Output:
# <REASONING>
#                     * Diff: Several changes made including adding `final` to parameters, adding log statements, and refactoring some methods.
#                     * Analysis:
#                         * Adding `final` to parameters is generally good practice, but it's not an evident defect by itself.
#                         * Log statements are useful for debugging, but they can clutter production logs if overused.
#                         * Refactoring methods like `refreshIfUserSwitched` improves maintainability, which is a positive aspect.
#                     * Conclusion: No evident defects.
#                     </REASONING>
#                     NoComment
# Parsed Reasoning:
# * Diff: Several changes made including adding `final` to parameters, adding log statements, and refactoring some methods.
#                     * Analysis:
#                         * Adding `final` to parameters is generally good practice, but it's not an evident defect by itself.
#                         * Log statements are useful for debugging, but they can clutter production logs if overused.
#                         * Refactoring methods like `refreshIfUserSwitched` improves maintainability, which is a positive aspect.
#                     * Conclusion: No evident defects.
# Parsed Review:
# NoComment
# --------------------
#
# --- Candidate 1 ---
# Full LLM Output:
# <REASONING>
#                     * Diff: Code reorganized and comments added.
#                     * Analysis:
#                         * No evident defects identified in the changed lines. The addition of logging and the restructuring of the code seem to improve readability and maintainability.
#                         * The method `refreshIfUserSwitched` is duplicated, which could lead to inconsistencies. However, this is more of a code smell than a defect.
#                     * Conclusion: No evident defects.
#                     </REASONING>
#                     NoComment
# Parsed Reasoning:
# * Diff: Code reorganized and comments added.
#                     * Analysis:
#                         * No evident defects identified in the changed lines. The addition of logging and the restructuring of the code seem to improve readability and maintainability.
#                         * The method `refreshIfUserSwitched` is duplicated, which could lead to inconsistencies. However, this is more of a code smell than a defect.
#                     * Conclusion: No evident defects.
# Parsed Review:
# NoComment
# --------------------
#
# --- Candidate 2 ---
# Full LLM Output:
# <REASONING>
#                     * Diff: Several changes were made to the `SalesforceReactActivity` class.
#                     * Analysis:
#                         * Added `final` keyword to parameters in `logData` method (not relevant to current diff).
#                         * Removed `UserSwitchReceiver` related code (not relevant to current diff).
#                         * Added logging statement in `onCreate` method (no evident defects).
#                         * `refreshIfUserSwitched` method duplicated in `onResume` and `refreshIfUserSwitched` (redundancy and potential inconsistency).
#                     * Conclusion: Evident defects identified.
#                     </REASONING>
#
#                     * Lines 78-81 and 144-147: Duplicate code. Refactor to avoid redundancy.
#                     * Lines 82-107: Consider removing commented-out code to keep the codebase clean.
#                     * Lines 138-141: Redundant call to `EventsObservable.get().notifyEvent(EventType.RenditionComplete);` that already occurs in `authenticatedRestClient`. Remove one occurrence to maintain consistency.
# Parsed Reasoning:
# * Diff: Several changes were made to the `SalesforceReactActivity` class.
#                     * Analysis:
#                         * Added `final` keyword to parameters in `logData` method (not relevant to current diff).
#                         * Removed `UserSwitchReceiver` related code (not relevant to current diff).
#                         * Added logging statement in `onCreate` method (no evident defects).
#                         * `refreshIfUserSwitched` method duplicated in `onResume` and `refreshIfUserSwitched` (redundancy and potential inconsistency).
#                     * Conclusion: Evident defects identified.
# Parsed Review:
# * Lines 78-81 and 144-147: Duplicate code. Refactor to avoid redundancy.
#                     * Lines 82-107: Consider removing commented-out code to keep the codebase clean.
#                     * Lines 138-141: Redundant call to `EventsObservable.get().notifyEvent(EventType.RenditionComplete);` that already occurs in `authenticatedRestClient`. Remove one occurrence to maintain consistency.
# --------------------
# BEST: NoComment
# ✓ 9/1940  id=15180
#
# --- Candidate 0 ---
# Full LLM Output:
# <REASONING>
#                     * Diff: Additional configuration settings added to `serverOptions` in lines 253-271.
#                     * Analysis: The changes add various HTTP configuration options such as `maxFormAttributeSize`, `compressionLevel`, `decompressionSupported`, etc. These additions are likely intended to improve the server's behavior based on configuration settings.
#                     * Conclusion: No evident defects.
#                     </REASONING>
#                     NoComment
# Parsed Reasoning:
# * Diff: Additional configuration settings added to `serverOptions` in lines 253-271.
#                     * Analysis: The changes add various HTTP configuration options such as `maxFormAttributeSize`, `compressionLevel`, `decompressionSupported`, etc. These additions are likely intended to improve the server's behavior based on configuration settings.
#                     * Conclusion: No evident defects.
# Parsed Review:
# NoComment
# --------------------
#
# --- Candidate 1 ---
# Full LLM Output:
# <REASONING>
# * Diff: Additional configuration options set for `HttpServerOptions`.
# * Analysis: These changes improve the flexibility of the HTTP server configuration without introducing bugs, performance issues, or significant readability issues. They are all best practices.
# * Conclusion: No evident defect.
# </REASONING>
# NoComment
# Parsed Reasoning:
# * Diff: Additional configuration options set for `HttpServerOptions`.
# * Analysis: These changes improve the flexibility of the HTTP server configuration without introducing bugs, performance issues, or significant readability issues. They are all best practices.
# * Conclusion: No evident defect.
# Parsed Review:
# NoComment
# --------------------
#
# --- Candidate 2 ---
# Full LLM Output:
# <REASONING>
#                     * Diff: Additional configuration options added to `serverOptions` in the `createDefaultHttpServerOptions` method (lines 253-272).
#                     * Analysis: These additions seem to be configuring various aspects of the HTTP server, such as compression level, chunk size, decompression support, and HTTP2 settings. There are no evident defects related to bugs, security, performance, or style.
#                     * Conclusion: No evident defects.
#                     </REASONING>
#                     NoComment
# Parsed Reasoning:
# * Diff: Additional configuration options added to `serverOptions` in the `createDefaultHttpServerOptions` method (lines 253-272).
#                     * Analysis: These additions seem to be configuring various aspects of the HTTP server, such as compression level, chunk size, decompression support, and HTTP2 settings. There are no evident defects related to bugs, security, performance, or style.
#                     * Conclusion: No evident defects.
# Parsed Review:
# NoComment
# --------------------
# BEST: NoComment
# ✓ 10/1940  id=12460
#
# --- Candidate 0 ---
# Full LLM Output:
# <REASONING>
#                     * Diff: Method signature changed on line 101. Changed lines include lines 101, 105, and 106.
#                     * Analysis: The addition of `final` to parameters improves immutability and reduces bugs related to accidental reassignment. However, there is no evidence of a bug, performance issue, or significant impact on readability/maintainability.
#                     * Conclusion: No evident defect.
#                     </REASONING>
#                     NoComment
# Parsed Reasoning:
# * Diff: Method signature changed on line 101. Changed lines include lines 101, 105, and 106.
#                     * Analysis: The addition of `final` to parameters improves immutability and reduces bugs related to accidental reassignment. However, there is no evidence of a bug, performance issue, or significant impact on readability/maintainability.
#                     * Conclusion: No evident defect.
# Parsed Review:
# NoComment
# --------------------
#
# --- Candidate 1 ---
# Full LLM Output:
# <REASONING>
# * Diff: Method signature changed from `Collector` constructor to remove `this.sampler` assignment.
# * Analysis: The diff removes the initialization of `this.sampler` but introduces a new field `handler`. However, there's no evidence of bugs, performance issues, or significant harm to readability/maintainability.
# * Conclusion: No evident defect.
# </REASONING>
# NoComment
# Parsed Reasoning:
# * Diff: Method signature changed from `Collector` constructor to remove `this.sampler` assignment.
# * Analysis: The diff removes the initialization of `this.sampler` but introduces a new field `handler`. However, there's no evidence of bugs, performance issues, or significant harm to readability/maintainability.
# * Conclusion: No evident defect.
# Parsed Review:
# NoComment
# --------------------
